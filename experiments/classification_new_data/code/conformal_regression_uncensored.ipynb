# %%
import pandas as pd
from constants import DATA_PATH, EOS_FILE, SENTINEL_FILE

sentinel = pd.read_csv(DATA_PATH / SENTINEL_FILE)
eos = pd.read_csv(DATA_PATH / EOS_FILE)

# %%
sentinel = sentinel[sentinel['SM1 (%)'] != 50]
eos = eos[eos['SM1 (%)'] != 50]

# %%
from constants import X_cols_eos, X_cols_sentinel, y_col

X_sentinel = sentinel[X_cols_sentinel].values
X_eos = eos[X_cols_eos].values

y_sentinel = sentinel[y_col].values
y_eos = eos[y_col].values

# %%
from model_experiments import ConformalRegression


cr = ConformalRegression(X_eos, y_eos, "EOS-04")
cr.run_experiment()
# Out:
# 2025-11-02 20:20:05.311095: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Split sizes:
#   Train    - X: (1636, 2), y: 1636 (80.0%)
#   Conformal- X: (204, 2), y: 204 (10.0%)
#   Test     - X: (205, 2), y: 205 (10.0%)
#   Original data rows: 2045
# ==========Running QuantileRegressor===========
#
#
# ==========Running GradientBoostingRegressor===========
#
#
# ==========Running HistGradientBoostingRegressor===========

# %%
from model_experiments import ConformalRegression


cr = ConformalRegression(X_sentinel, y_sentinel, "Sentinel-1")
cr.run_experiment()
# Out:
# Split sizes:
#   Train    - X: (1220, 2), y: 1220 (80.0%)
#   Conformal- X: (152, 2), y: 152 (10.0%)
#   Test     - X: (153, 2), y: 153 (10.0%)
#   Original data rows: 1525
# ==========Running QuantileRegressor===========
#
#
# ==========Running GradientBoostingRegressor===========
#
#
# ==========Running HistGradientBoostingRegressor===========
