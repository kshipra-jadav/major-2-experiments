# %%
import pandas as pd
from constants import DATA_PATH, EOS_FILE, SENTINEL_FILE

sentinel = pd.read_csv(DATA_PATH / SENTINEL_FILE)
eos = pd.read_csv(DATA_PATH / EOS_FILE)

# %%
sentinel = sentinel[sentinel['SM1 (%)'] != 50]
eos = eos[eos['SM1 (%)'] != 50]

# %%
from constants import X_cols_eos, X_cols_sentinel, y_col

X_sentinel = sentinel[X_cols_sentinel].values
X_eos = eos[X_cols_eos].values

y_sentinel = sentinel[y_col].values
y_eos = eos[y_col].values

# %%
import tensorflow as tf
# Out:
# 2025-11-26 07:45:08.098690: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
models = {
#     "16, 1": tf.keras.Sequential([
#     # Input layer
#     tf.keras.Input(shape=(2, )),
#     tf.keras.layers.Dense(16, activation='relu'),
#     tf.keras.layers.Dense(1)
# ]),
#     "8, 1": tf.keras.Sequential([
#     # Input layer
#     tf.keras.Input(shape=(2, )),
#     tf.keras.layers.Dense(8, activation='relu'),
#     tf.keras.layers.Dense(1)
# ]),
#     "2, 1": tf.keras.Sequential([
#     # Input layer
#     tf.keras.Input(shape=(2, )),
#     tf.keras.layers.Dense(2, activation='relu'),
#     tf.keras.layers.Dense(1)
# ]),
#     "4, 1": tf.keras.Sequential([
#     # Input layer
#     tf.keras.Input(shape=(2, )),
#     tf.keras.layers.Dense(4, activation='relu'),
#     tf.keras.layers.Dense(1)
# ]),
    "16, Dropout, 8, Dropout": tf.keras.Sequential([
    # Input layer
    tf.keras.Input(shape=(2, )),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dropout(0.09),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dropout(0.09),
    tf.keras.layers.Dense(1)
]),
    "16, Dropout": tf.keras.Sequential([
    # Input layer
    tf.keras.Input(shape=(2, )),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(1)
])
}

# %%
from model_experiments import ConformalizedQuantileExperiment

eos_exp = ConformalizedQuantileExperiment(X_eos, y_eos, satellite="EOS-04")

eos_results = eos_exp.run_ann_tuning_experiment(models["16, Dropout, 8, Dropout"])
# Out:
# === Starting Tau Hyperparameter Tuning for EOS-04 ===
#
# Running configuration: Low:0.01 - High:0.96
# Epochs:  22%|██▏       | 22/100 [00:05<00:20,  3.75epoch/s, loss=1.4930, val_loss=1.0627]
# Epochs:  16%|█▌        | 16/100 [00:03<00:20,  4.06epoch/s, loss=0.1818, val_loss=0.1830]
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#   > CQR Calibration constant (Q): -0.6709
#
# Running configuration: Low:0.015 - High:0.965
# Epochs:  21%|██        | 21/100 [00:03<00:12,  6.46epoch/s, loss=1.2168, val_loss=0.9460]
# Epochs:  27%|██▋       | 27/100 [00:03<00:10,  6.92epoch/s, loss=0.2677, val_loss=0.2667]
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#   > CQR Calibration constant (Q): -0.9508
#
# Running configuration: Low:0.02 - High:0.97
# Epochs:  21%|██        | 21/100 [00:03<00:12,  6.57epoch/s, loss=1.0171, val_loss=0.8395]
# Epochs:  30%|███       | 30/100 [00:04<00:10,  6.96epoch/s, loss=0.3538, val_loss=0.3518]
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#   > CQR Calibration constant (Q): -1.0229
#
# Running configuration: Low:0.025 - High:0.975
# Epochs:  24%|██▍       | 24/100 [00:04<00:13,  5.60epoch/s, loss=1.0357, val_loss=0.7400]
# Epochs:  29%|██▉       | 29/100 [00:04<00:11,  6.39epoch/s, loss=0.4357, val_loss=0.4325]
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#   > CQR Calibration constant (Q): -1.1503
#
# Running configuration: Low:0.03 - High:0.98
# Epochs:  24%|██▍       | 24/100 [00:03<00:11,  6.60epoch/s, loss=0.8503, val_loss=0.6138]
# Epochs:  27%|██▋       | 27/100 [00:04<00:11,  6.45epoch/s, loss=0.5219, val_loss=0.5162]
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#   > CQR Calibration constant (Q): -1.2606
#
# Running configuration: Low:0.04 - High:0.99
# Epochs:  24%|██▍       | 24/100 [00:03<00:12,  6.19epoch/s, loss=0.4435, val_loss=0.3413]
# Epochs:  49%|████▉     | 49/100 [00:07<00:07,  6.91epoch/s, loss=0.6773, val_loss=0.6636]
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#   > CQR Calibration constant (Q): -1.0147
# Tuning metrics saved to /home/kshipra/work/coding/major/ml experiments/experiments/classification_new_data/output/conformal_results/EOS-04_tau_tuning_metrics.json

# %%
sentinel_exp = ConformalizedQuantileExperiment(X_sentinel, y_sentinel, satellite="Sentinel-1")

sentinel_results = sentinel_exp.run_ann_tuning_experiment(models['16, Dropout, 8, Dropout'])
# Out:
# === Starting Tau Hyperparameter Tuning for Sentinel-1 ===
#
# Running configuration: Low:0.01 - High:0.96
# Epochs:  29%|██▉       | 29/100 [00:06<00:15,  4.44epoch/s, loss=1.3229, val_loss=1.0328]
# Epochs:  56%|█████▌    | 56/100 [00:07<00:06,  7.10epoch/s, loss=0.1930, val_loss=0.1976]
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/stepWARNING:tensorflow:5 out of the last 25 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fdabdda9580> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#   > CQR Calibration constant (Q): 0.3064
#
# Running configuration: Low:0.015 - High:0.965
# Epochs:  27%|██▋       | 27/100 [00:03<00:09,  7.62epoch/s, loss=1.2300, val_loss=0.9344]
# Epochs:  23%|██▎       | 23/100 [00:03<00:10,  7.42epoch/s, loss=0.2890, val_loss=0.2921]
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/stepWARNING:tensorflow:5 out of the last 21 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fdabce25080> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#   > CQR Calibration constant (Q): 0.2549
#
# Running configuration: Low:0.02 - High:0.97
# Epochs:  27%|██▋       | 27/100 [00:04<00:11,  6.49epoch/s, loss=1.1923, val_loss=0.8300]
# Epochs:  16%|█▌        | 16/100 [00:02<00:13,  6.41epoch/s, loss=0.3773, val_loss=0.3853]
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#   > CQR Calibration constant (Q): 0.4608
#
# Running configuration: Low:0.025 - High:0.975
# Epochs:  25%|██▌       | 25/100 [00:03<00:10,  7.30epoch/s, loss=0.8718, val_loss=0.7001]
# Epochs:  15%|█▌        | 15/100 [00:02<00:12,  6.57epoch/s, loss=0.4626, val_loss=0.4772]
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#   > CQR Calibration constant (Q): 0.2596
#
# Running configuration: Low:0.03 - High:0.98
# Epochs:  36%|███▌      | 36/100 [00:04<00:08,  7.99epoch/s, loss=1.2803, val_loss=0.6055]
# Epochs:  23%|██▎       | 23/100 [00:03<00:10,  7.26epoch/s, loss=0.5438, val_loss=0.5657]
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#   > CQR Calibration constant (Q): -0.3479
#
# Running configuration: Low:0.04 - High:0.99
# Epochs:  31%|███       | 31/100 [00:04<00:09,  7.62epoch/s, loss=0.4993, val_loss=0.3303]
# Epochs:  24%|██▍       | 24/100 [00:03<00:10,  7.57epoch/s, loss=0.7198, val_loss=0.7377]
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#   > CQR Calibration constant (Q): 0.0019
# Tuning metrics saved to /home/kshipra/work/coding/major/ml experiments/experiments/classification_new_data/output/conformal_results/Sentinel-1_tau_tuning_metrics.json

# %%
eos_results
# Out:
#                  Tau_Pair  Raw_PICP   Raw_MPIW  CQR_PICP   CQR_MPIW
# 0    Low:0.01 - High:0.96  0.926829  38.264690  0.921951  36.922950
# 1  Low:0.015 - High:0.965  0.946341  39.157101  0.917073  37.255501
# 2    Low:0.02 - High:0.97  0.956098  39.514618  0.921951  37.468784
# 3  Low:0.025 - High:0.975  0.965854  41.020721  0.921951  38.720172
# 4    Low:0.03 - High:0.98  0.970732  41.985928  0.912195  39.464690
# 5    Low:0.04 - High:0.99  0.970732  43.661911  0.921951  41.632582

# %%
sentinel_results
# Out:
#                  Tau_Pair  Raw_PICP   Raw_MPIW  CQR_PICP   CQR_MPIW
# 0    Low:0.01 - High:0.96  0.934641  39.198410  0.934641  39.811195
# 1  Low:0.015 - High:0.965  0.934641  39.683472  0.941176  40.193325
# 2    Low:0.02 - High:0.97  0.934641  40.093685  0.941176  41.015352
# 3  Low:0.025 - High:0.975  0.941176  40.335571  0.947712  40.854707
# 4    Low:0.03 - High:0.98  0.941176  41.169113  0.934641  40.473246
# 5    Low:0.04 - High:0.99  0.941176  42.173309  0.941176  42.177090
