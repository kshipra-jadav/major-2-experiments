# %%
import pandas as pd
from constants import DATA_PATH, EOS_FILE, SENTINEL_FILE

sentinel = pd.read_csv(DATA_PATH / SENTINEL_FILE)
eos = pd.read_csv(DATA_PATH / EOS_FILE)

# %%
from constants import X_cols_eos, X_cols_sentinel, y_col

X_sentinel = sentinel[X_cols_sentinel].values
X_eos = eos[X_cols_eos].values

y_sentinel = sentinel[y_col].values
y_eos = eos[y_col].values

# %%
from model_experiments import RegressionExperiment

re = RegressionExperiment(X_eos, y_eos, satellite="EOS-04", train_size=0.8, test_size=0.2, split_type='train-test')
re.run_experiment()
# Out:
# === Running RandomForest for EOS-04 ===
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# RandomForest Test R2 Score - 10.7056
# === Running XGBoost for EOS-04 ===
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# XGBoost Test R2 Score - 10.7879
# === Running AdaBoost for EOS-04 ===
# Fitting 3 folds for each of 144 candidates, totalling 432 fits
# AdaBoost Test R2 Score - 9.9087
# === Running SVR for EOS-04 ===
# Fitting 3 folds for each of 320 candidates, totalling 960 fits
# SVR Test R2 Score - 4.7207
# Metrics saved successfully.
# {'RandomForest': {'MAE': 12.8439,
#   'MSE': 232.2897,
#   'RMSE': 15.2411,
#   'R2': 0.1071,
#   'MAPE': 1.0667},
#  'XGBoost': {'MAE': 12.937,
#   'MSE': 232.0755,
#   'RMSE': 15.234,
#   'R2': 0.1079,
#   'MAPE': 1.0852},
#  'AdaBoost': {'MAE': 13.0478,
#   'MSE': 234.3627,
#   'RMSE': 15.3089,
#   'R2': 0.0991,
#   'MAPE': 1.1137},
#  'SVR': {'MAE': 12.6688,
#   'MSE': 247.8587,
#   'RMSE': 15.7435,
#   'R2': 0.0472,
#   'MAPE': 0.8819}}

# %%
re = RegressionExperiment(X_sentinel, y_sentinel, satellite="Sentinel-1", train_size=0.8, test_size=0.2, split_type='train-test')
re.run_experiment()
# Out:
# === Running RandomForest for Sentinel-1 ===
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# RandomForest Test R2 Score - 15.3883
# === Running XGBoost for Sentinel-1 ===
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# XGBoost Test R2 Score - 14.1942
# === Running AdaBoost for Sentinel-1 ===
# Fitting 3 folds for each of 144 candidates, totalling 432 fits
# AdaBoost Test R2 Score - 14.8068
# === Running SVR for Sentinel-1 ===
# Fitting 3 folds for each of 320 candidates, totalling 960 fits
# SVR Test R2 Score - 10.2451
# Metrics saved successfully.
# {'RandomForest': {'MAE': 11.7321,
#   'MSE': 200.5317,
#   'RMSE': 14.1609,
#   'R2': 0.1539,
#   'MAPE': 0.8372},
#  'XGBoost': {'MAE': 11.8741,
#   'MSE': 203.3618,
#   'RMSE': 14.2605,
#   'R2': 0.1419,
#   'MAPE': 0.85},
#  'AdaBoost': {'MAE': 11.8316,
#   'MSE': 201.9099,
#   'RMSE': 14.2095,
#   'R2': 0.1481,
#   'MAPE': 0.8525},
#  'SVR': {'MAE': 11.2713,
#   'MSE': 212.7213,
#   'RMSE': 14.585,
#   'R2': 0.1025,
#   'MAPE': 0.6473}}
